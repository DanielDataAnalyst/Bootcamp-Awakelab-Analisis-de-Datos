# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielDataAnalyst/Bootcamp-Awakelab-Analisis-de-Datos/blob/main/M3_AE2_Ejercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Escribir un programa que pregunte al usuario por las ventas de un rango de años y muestre por pantalla una serie con los datos de las ventas indexada por los años, antes y después de aplicarles un descuento del 10%.

# %%
import pandas as pd

sales_year = {"Year":{}, "Sales":{}}
first_year = int(input("Introduzca el año inicial: "))
last_year = int(input("Introduzca el año final: "))

for i in range(first_year, last_year+1):
  sales_year["Year"][i] = int(input(f"Introduzca las ventas del año {i}: "))
  #sales_year["Sales"] = 

print(sales_year)
# Out:
# Introduzca el año inicial: 2020
# Introduzca el año final: 2021
# Introduzca las ventas del año 2020: 56
# Introduzca las ventas del año 2021: 23
# {'Year': {2020: 56, 2021: 23}, 'Sales': {}}

# %% [markdown]
# 2. Escribir una función que reciba un diccionario con las notas de los alumnos en curso en un examen y devuelva una serie con la nota mínima, la máxima, media y la desviación típica.

# %% [markdown]
# 3. Escribir una función que reciba una diccionario con las notas de los alumnos en curso en un examen y devuelva una serie con las notas de los alumnos aprobados ordenadas de mayor a menor.

# %% [markdown]
# 4. Escribir programa que genere y muestre por pantalla un DataFrame con los datos de la tabla siguiente:
#
#
# ![Sin título.jpg](data:image/jpeg;base64,...)
